# %%
import pandas as pd
df = pd.read_csv('../datasets/game_sales.csv')

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.sort_values("Year", ascending=False).head()
# Out:
#         Rank                                              Name Platform  \
# 5957    5959                            Imagine: Makeup Artist       DS
# 14390  14393  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 16241  16244  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 16438  16441                  Brothers Conflict: Precious Baby      PSV
# 8293    8295                      Shin Megami Tensei IV: Final      3DS
#
#          Year         Genre     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 5957   2020.0    Simulation       Ubisoft      0.27       0.0      0.00
# 14390  2017.0  Role-Playing          Sega      0.00       0.0      0.03
# 16241  2017.0  Role-Playing          Sega      0.00       0.0      0.01
# 16438  2017.0        Action  Idea Factory      0.00       0.0      0.01
# 8293   2016.0  Role-Playing   Deep Silver      0.03       0.0      0.14
#
#        Other_Sales  Global_Sales
# 5957          0.02          0.29
# ...

# %%
df.sort_values("Year").head()
# Out:
#       Rank      Name Platform    Year     Genre   Publisher  NA_Sales  \
# 6896  6898  Checkers     2600  1980.0      Misc       Atari      0.22
# 2669  2671    Boxing     2600  1980.0  Fighting  Activision      0.72
# 5366  5368   Freeway     2600  1980.0    Action  Activision      0.32
# 1969  1971  Defender     2600  1980.0      Misc       Atari      0.99
# 1766  1768   Kaboom!     2600  1980.0      Misc  Activision      1.07
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 6896      0.01       0.0         0.00          0.24
# 2669      0.04       0.0         0.01          0.77
# 5366      0.02       0.0         0.00          0.34
# 1969      0.05       0.0         0.01          1.05
# 1766      0.07       0.0         0.01          1.15

# %%
df.sort_values(["Year", "Global_Sales"]).head()
# Out:
#       Rank        Name Platform    Year     Genre   Publisher  NA_Sales  \
# 6896  6898    Checkers     2600  1980.0      Misc       Atari      0.22
# 6317  6319      Bridge     2600  1980.0      Misc  Activision      0.25
# 5366  5368     Freeway     2600  1980.0    Action  Activision      0.32
# 4025  4027  Ice Hockey     2600  1980.0    Sports  Activision      0.46
# 2669  2671      Boxing     2600  1980.0  Fighting  Activision      0.72
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 6896      0.01       0.0         0.00          0.24
# 6317      0.02       0.0         0.00          0.27
# 5366      0.02       0.0         0.00          0.34
# 4025      0.03       0.0         0.01          0.49
# 2669      0.04       0.0         0.01          0.77

# %%
df.sort_values(["Year", "Global_Sales"], ascending=[True, False]).head()
# Out:
#       Rank             Name Platform    Year     Genre   Publisher  NA_Sales  \
# 258    259        Asteroids     2600  1980.0   Shooter       Atari      4.00
# 544    545  Missile Command     2600  1980.0   Shooter       Atari      2.56
# 1766  1768          Kaboom!     2600  1980.0      Misc  Activision      1.07
# 1969  1971         Defender     2600  1980.0      Misc       Atari      0.99
# 2669  2671           Boxing     2600  1980.0  Fighting  Activision      0.72
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 258       0.26       0.0         0.05          4.31
# 544       0.17       0.0         0.03          2.76
# 1766      0.07       0.0         0.01          1.15
# 1969      0.05       0.0         0.01          1.05
# 2669      0.04       0.0         0.01          0.77

# %%
df["Name"].head()
# Out:
# 0                  Wii Sports
# 1           Super Mario Bros.
# 2              Mario Kart Wii
# 3           Wii Sports Resort
# 4    Pokemon Red/Pokemon Blue
# Name: Name, dtype: object

# %%
df[["Year", "Name"]].head()
# Out:
#      Year                      Name
# 0  2006.0                Wii Sports
# 1  1985.0         Super Mario Bros.
# 2  2008.0            Mario Kart Wii
# 3  2009.0         Wii Sports Resort
# 4  1996.0  Pokemon Red/Pokemon Blue

# %%
subset = ["Genre", "Year", "Global_Sales"]
df[subset].head()
# Out:
#           Genre    Year  Global_Sales
# 0        Sports  2006.0         82.74
# 1      Platform  1985.0         40.24
# 2        Racing  2008.0         35.82
# 3        Sports  2009.0         33.00
# 4  Role-Playing  1996.0         31.37

# %%
filtr = df["Year"] > 2016
print(filtr)

df[filtr].head()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16593    False
# 16594    False
# 16595    False
# 16596    False
# 16597    False
# Name: Year, Length: 16598, dtype: bool
#         Rank                                              Name Platform  \
# 5957    5959                            Imagine: Makeup Artist       DS
# 14390  14393  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 16241  16244  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 16438  16441                  Brothers Conflict: Precious Baby      PSV
#
#          Year         Genre     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 5957   2020.0    Simulation       Ubisoft      0.27       0.0      0.00
# 14390  2017.0  Role-Playing          Sega      0.00       0.0      0.03
# 16241  2017.0  Role-Playing          Sega      0.00       0.0      0.01
# 16438  2017.0        Action  Idea Factory      0.00       0.0      0.01
#
# ...

# %%
df[df["Global_Sales"] > 30].head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df[df["Genre"] == "Strategy"].head()
# Out:
#      Rank                            Name Platform    Year     Genre  \
# 165   166                 Pokemon Stadium      N64  1999.0  Strategy
# 204   205                    Warzone 2100       PS  1999.0  Strategy
# 217   218  StarCraft II: Wings of Liberty       PC  2010.0  Strategy
# 267   268  Warcraft II: Tides of Darkness       PC  1995.0  Strategy
# 335   336       Pokémon Trading Card Game       GB  1998.0  Strategy
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 165           Nintendo      3.18      1.24      0.94         0.09
# 204  Eidos Interactive      2.79      1.89      0.00         0.33
# 217         Activision      2.56      1.68      0.00         0.59
# 267         Activision      1.70      2.27      0.00         0.23
# 335           Nintendo      1.49      0.73      1.38         0.10
#
#      Global_Sales
# 165          5.45
# 204          5.01
# 217          4.83
# 267          4.21
# 335          3.70

# %%
# Generate random dates between range.
import numpy as np
df["Dates"] = pd.to_datetime(
    np.random.randint(
        pd.to_datetime('2015-01-01').value//10**9,
        pd.to_datetime('2018-01-01').value//10**9,
        df.shape[0]
    ), unit='s')

df[df["Dates"] > "2017-01-01"].head()
# Out:
#     Rank                      Name Platform    Year         Genre Publisher  \
# 2      3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 4      5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5      6                    Tetris       GB  1989.0        Puzzle  Nintendo
# 10    11                Nintendogs       DS  2005.0    Simulation  Nintendo
# 14    15              Wii Fit Plus      Wii  2009.0        Sports  Nintendo
#
#     NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 2      15.85     12.88      3.79         3.31         35.82
# 4      11.27      8.89     10.22         1.00         31.37
# 5      23.20      2.26      4.22         0.58         30.26
# 10      9.07     11.00      1.93         2.75         24.76
# 14      9.09      8.59      2.53         1.79         22.00
#
#                  Dates
# 2  2017-03-14 20:03:40
# 4  2017-10-20 19:48:25
# 5  2017-08-14 05:32:28
# 10 2017-04-15 01:51:51
# 14 2017-05-22 01:45:22

# %%
is_strategy = df["Genre"] == "Strategy"
is_pc = df["Platform"] == "PC"

df[is_strategy & is_pc].head()
# Out:
#      Rank                            Name Platform    Year     Genre  \
# 217   218  StarCraft II: Wings of Liberty       PC  2010.0  Strategy
# 267   268  Warcraft II: Tides of Darkness       PC  1995.0  Strategy
# 511   512    Command & Conquer: Red Alert       PC  1996.0  Strategy
# 648   649                  Theme Hospital       PC  1997.0  Strategy
# 805   807                  Sim Theme Park       PC  1998.0  Strategy
#
#               Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 217          Activision      2.56      1.68       0.0         0.59
# 267          Activision      1.70      2.27       0.0         0.23
# 511  Virgin Interactive      1.37      1.34       0.0         0.14
# 648     Electronic Arts      2.30      0.10       0.0         0.00
# 805     Electronic Arts      2.04      0.04       0.0         0.00
#
#      Global_Sales               Dates
# 217          4.83 2016-07-02 08:42:38
# 267          4.21 2015-11-22 05:00:08
# ...

# %%
df[(df["Publisher"] == "Nintendo") & (df["Genre"] == "Strategy")].head()
# Out:
#       Rank                       Name Platform    Year     Genre Publisher  \
# 165    166            Pokemon Stadium      N64  1999.0  Strategy  Nintendo
# 335    336  Pokémon Trading Card Game       GB  1998.0  Strategy  Nintendo
# 547    548          Pokémon Stadium 2      N64  2000.0  Strategy  Nintendo
# 1125  1127                     Pikmin       GC  2001.0  Strategy  Nintendo
# 1421  1423    Pocket Monsters Stadium      N64  1998.0  Strategy  Nintendo
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 165       3.18      1.24      0.94         0.09          5.45
# 335       1.49      0.73      1.38         0.10          3.70
# 547       1.02      0.36      1.13         0.23          2.73
# 1125      0.78      0.25      0.56         0.04          1.63
# 1421      0.00      0.00      1.37         0.00          1.37
#
#                    Dates
# 165  2017-01-06 14:36:08
# 335  2017-04-14 16:04:36
# 547  2015-11-16 06:24:05
# 1125 2015-10-06 01:12:32
# ...

# %%
is_strategy_or_simulation = df["Genre"].isin(["Strategy", "Simulation"])

df[is_strategy_or_simulation]
# Out:
#         Rank                                   Name Platform    Year  \
# 10        11                             Nintendogs       DS  2005.0
# 41        42            Animal Crossing: Wild World       DS  2005.0
# 73        74              Animal Crossing: New Leaf      3DS  2012.0
# 83        84                             The Sims 3       PC  2009.0
# 153      154                           Cooking Mama       DS  2006.0
# ...      ...                                    ...      ...     ...
# 16539  16542              Spore Galactic Adventures       PC  2009.0
# 16555  16558  Codename: Panzers Complete Collection       PC  2016.0
# 16566  16569                         End of Nations       PC  2012.0
# 16570  16573          Farming 2017 - The Simulation      PS4  2016.0
# 16592  16595                               Plushees       DS  2008.0
#
#             Genre          Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 10     Simulation           Nintendo      9.07     11.00      1.93
# ...
