# %%
import pandas as pd
df = pd.read_csv('./datasets/game_sales.csv')

# %%
df.head()
# Out:
#                        name platform    year         genre publisher  \
# 0                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue        G  1996.0  Role-Playing  Nintendo
#
#    na_sales  eu_sales  jp_sales  other_sales  global_sales  critic_score  \
# 0     41.36     28.96      3.77         8.45         82.54          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.80      3.79         3.29         35.57          82.0
# 3     15.61     10.95      3.28         2.95         32.78          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    critic_count  user_score  user_count rating        date
# 0          51.0         8.0       324.0      E  2006-10-09
# 1           NaN         NaN         NaN    NaN  1985-01-20
# 2          73.0         8.3       712.0      E  2008-11-16
# 3          73.0         8.0       193.0      E  2009-11-25
# 4           NaN         NaN         NaN    NaN  1996-08-17

# %%
# Group by two variables.
pt = df.pivot_table(values="global_sales", index="genre", columns="platform", aggfunc=sum)

pt.head()
# Out:
# platform    2600   3DO    3DS    DC      DS      G    GBA     GC    GEN    GG  \
# genre
# Action     29.34   NaN  59.92  1.26  112.86   7.92  55.80  37.84   2.74   NaN
# Adventure   1.70  0.06   5.05  2.50   46.19  17.16  14.70   5.93   0.19   NaN
# Fighting    1.24   NaN  10.67  1.83    7.12    NaN   4.21  18.43   5.90   NaN
# Misc        3.58   NaN  11.67   NaN  136.02  13.35  36.28  16.73   0.03   NaN
# Platform   13.27   NaN  34.29  2.54   75.98  54.91  78.32  28.66  15.45  0.04
#
# platform   ...   SAT  SCD   SNES  TG16  WS     Wii   WiiU      X    X360  \
# genre      ...
# Action     ...  0.65  NaN  10.08   NaN NaN  114.45  19.63  49.28  240.69
# Adventure  ...  4.16  NaN   1.50  0.14 NaN   17.88   0.19   3.07   15.20
# Fighting   ...  8.52  NaN  26.95   NaN NaN   23.74   6.45  13.55   37.43
# Misc       ...  1.20  0.1   5.02   NaN NaN  217.22  13.13   9.58   92.00
# Platform   ...  0.76  1.5  65.65   NaN NaN   89.13  22.18   9.66   11.42
#
# platform    XOne
# genre
# Action     40.24
# Adventure   2.97
# Fighting    2.55
# Misc        8.42
# Platform    1.02
#
# [5 rows x 31 columns]

# %%
# Pivot tables are just DataFrames with sorted indexes.

pt.loc["Adventure":"Platform"]
# Out:
# platform    2600   3DO    3DS    DC      DS      G    GBA     GC    GEN    GG  \
# genre
# Adventure   1.70  0.06   5.05  2.50   46.19  17.16  14.70   5.93   0.19   NaN
# Fighting    1.24   NaN  10.67  1.83    7.12    NaN   4.21  18.43   5.90   NaN
# Misc        3.58   NaN  11.67   NaN  136.02  13.35  36.28  16.73   0.03   NaN
# Platform   13.27   NaN  34.29  2.54   75.98  54.91  78.32  28.66  15.45  0.04
#
# platform   ...   SAT  SCD   SNES  TG16  WS     Wii   WiiU      X   X360  XOne
# genre      ...
# Adventure  ...  4.16  NaN   1.50  0.14 NaN   17.88   0.19   3.07  15.20  2.97
# Fighting   ...  8.52  NaN  26.95   NaN NaN   23.74   6.45  13.55  37.43  2.55
# Misc       ...  1.20  0.1   5.02   NaN NaN  217.22  13.13   9.58  92.00  8.42
# Platform   ...  0.76  1.5  65.65   NaN NaN   89.13  22.18   9.66  11.42  1.02
#
# [4 rows x 31 columns]

# %%
pt.loc["Adventure":"Platform", "PC":"PS4"]
# Out:
# platform      PC  PCFX     PS     PS2    PS3   PS4
# genre
# Adventure  10.34   NaN  20.98   21.45  22.50  7.21
# Fighting    0.29   NaN  72.68   92.63  51.26  9.13
# Misc        8.74   NaN  44.91  101.16  47.25  8.93
# Platform    0.51   NaN  64.21   72.51  29.83  8.31

# %%
# axis=index (default) means calculate the statistic across rows.
pt.sum(axis="index").sort_values(ascending=False).head()
# Out:
# platform
# PS2     1256.09
# X360     975.43
# PS3      943.29
# Wii      910.14
# DS       808.82
# dtype: float64

# %%
# axis=index means calculate the statistic across columns.

# useful for pivot tables but for dataframes, this doesn't
# makes sense since every column has different data type.

pt.sum(axis="columns").sort_values(ascending=False).head()
# Out:
# genre
# Action          1761.89
# Sports          1340.99
# Shooter         1067.28
# Role-Playing     949.31
# Platform         831.74
# dtype: float64
