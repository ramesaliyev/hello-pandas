# %%
import pandas as pd
df = pd.read_csv('./datasets/game_sales.csv')

# %%
df.head()
# Out:
#                        name platform    year         genre publisher  \
# 0                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue        G  1996.0  Role-Playing  Nintendo
#
#    na_sales  eu_sales  jp_sales  other_sales  global_sales  critic_score  \
# 0     41.36     28.96      3.77         8.45         82.54          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.80      3.79         3.29         35.57          82.0
# 3     15.61     10.95      3.28         2.95         32.78          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    critic_count  user_score  user_count rating        date
# ...

# %%
df.sort_values("year", ascending=False).head()
# Out:
#                                                    name platform    year  \
# 17050                     Saka Agari Hurricane Portable      PSV  2017.0
# 16551                                    ClaDun Sengoku      PSV  2017.0
# 16001  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV  2017.0
# 13726  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4  2017.0
# 16079                  Brothers Conflict: Precious Baby      PSV  2017.0
#
#               genre             publisher  na_sales  eu_sales  jp_sales  \
# 17050     Adventure             Entergram       0.0       0.0      0.01
# 16551        Action  Nippon Ichi Software       0.0       0.0      0.01
# 16001  Role-Playing                  Sega       0.0       0.0      0.02
# 13726  Role-Playing                  Sega       0.0       0.0      0.04
# 16079        Action          Idea Factory       0.0       0.0      0.02
#
#        other_sales  global_sales  critic_score  critic_count  user_score  \
# ...

# %%
df.sort_values("year").head()
# Out:
#                 name platform    year   genre publisher  na_sales  eu_sales  \
# 4472  Super Breakout     2600  1976.0  Puzzle     Atari      0.41      0.03
# 6304        Indy 500     2600  1977.0  Racing     Atari      0.26      0.01
# 1596          Combat     2600  1977.0  Action     Atari      1.17      0.07
# 4252    Circus Atari     2600  1977.0  Action     Atari      0.43      0.03
# 5074         Hangman     2600  1978.0  Puzzle     Atari      0.35      0.02
#
#       jp_sales  other_sales  global_sales  critic_score  critic_count  \
# 4472       0.0         0.00          0.44           NaN           NaN
# 6304       0.0         0.00          0.27           NaN           NaN
# 1596       0.0         0.01          1.25           NaN           NaN
# 4252       0.0         0.00          0.46           NaN           NaN
# 5074       0.0         0.00          0.38           NaN           NaN
#
#       user_score  user_count rating        date
# ...

# %%
df.sort_values(["year", "user_score"]).head()
# Out:
#                 name platform    year    genre publisher  na_sales  eu_sales  \
# 4472  Super Breakout     2600  1976.0   Puzzle     Atari      0.41      0.03
# 1596          Combat     2600  1977.0   Action     Atari      1.17      0.07
# 4252    Circus Atari     2600  1977.0   Action     Atari      0.43      0.03
# 6304        Indy 500     2600  1977.0   Racing     Atari      0.26      0.01
# 614   Space Invaders     2600  1978.0  Shooter     Atari      2.36      0.14
#
#       jp_sales  other_sales  global_sales  critic_score  critic_count  \
# 4472       0.0         0.00          0.44           NaN           NaN
# 1596       0.0         0.01          1.25           NaN           NaN
# 4252       0.0         0.00          0.46           NaN           NaN
# 6304       0.0         0.00          0.27           NaN           NaN
# 614        0.0         0.03          2.53           NaN           NaN
#
#       user_score  user_count rating        date
# ...

# %%
df.sort_values(["user_score", "global_sales"], ascending=[False, False]).head()
# Out:
#                                                 name platform    year  \
# 14480                             Breath of Fire III      PSP  2005.0
# 2415   Dragon Quest VIII: Journey of the Cursed King      3DS  2015.0
# 3437           Harvest Moon: Friends of Mineral Town      GBA  2003.0
# 9037                 Boktai: The Sun is in Your Hand      GBA  2003.0
# 1655                        Golden Sun: The Lost Age      GBA  2002.0
#
#               genre                     publisher  na_sales  eu_sales  \
# 14480  Role-Playing                        Capcom      0.00      0.02
# 2415   Role-Playing                   Square Enix      0.00      0.00
# 3437     Simulation                       Ubisoft      0.34      0.13
# 9037   Role-Playing  Konami Digital Entertainment      0.10      0.04
# 1655   Role-Playing                      Nintendo      0.61      0.27
#
#        jp_sales  other_sales  global_sales  critic_score  critic_count  \
# ...

# %%
df["name"].head()
# Out:
# 0                  Wii Sports
# 1           Super Mario Bros.
# 2              Mario Kart Wii
# 3           Wii Sports Resort
# 4    Pokemon Red/Pokemon Blue
# Name: name, dtype: object

# %%
df[["name", "year"]].head()
# Out:
#                        name    year
# 0                Wii Sports  2006.0
# 1         Super Mario Bros.  1985.0
# 2            Mario Kart Wii  2008.0
# 3         Wii Sports Resort  2009.0
# 4  Pokemon Red/Pokemon Blue  1996.0

# %%
subset = ["name", "year", "user_score"]
df[subset].head()
# Out:
#                        name    year  user_score
# 0                Wii Sports  2006.0         8.0
# 1         Super Mario Bros.  1985.0         NaN
# 2            Mario Kart Wii  2008.0         8.3
# 3         Wii Sports Resort  2009.0         8.0
# 4  Pokemon Red/Pokemon Blue  1996.0         NaN

# %%
filtr = df["user_score"] > 8
print(filtr)

df[filtr].head()
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 17403    False
# 17404    False
# 17405    False
# 17406    False
# 17407    False
# Name: user_score, Length: 17408, dtype: bool
#                          name platform    year     genre  \
# 2              Mario Kart Wii      Wii  2008.0    Racing
# 6       New Super Mario Bros.       DS  2006.0  Platform
# 8   New Super Mario Bros. Wii      Wii  2009.0  Platform
# 11              Mario Kart DS       DS  2005.0    Racing
# 16         Grand Theft Auto V      PS3  2013.0    Action
#
#                publisher  na_sales  eu_sales  jp_sales  other_sales  \
# 2               Nintendo     15.68     12.80      3.79         3.29
# 6               Nintendo     11.28      9.15      6.50         2.88
# 8               Nintendo     14.48      6.95      4.70         2.25
# 11              Nintendo      9.71      7.48      4.13         1.90
# ...

# %%
df[df["global_sales"] > 30].head()
# Out:
#                        name platform    year         genre publisher  \
# 0                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue        G  1996.0  Role-Playing  Nintendo
#
#    na_sales  eu_sales  jp_sales  other_sales  global_sales  critic_score  \
# 0     41.36     28.96      3.77         8.45         82.54          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.80      3.79         3.29         35.57          82.0
# 3     15.61     10.95      3.28         2.95         32.78          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    critic_count  user_score  user_count rating        date
# ...

# %%
df[df["genre"] == "Strategy"].head()
# Out:
#                                  name platform    year     genre  \
# 170                   Pokemon Stadium      N64  1999.0  Strategy
# 209                      Warzone 2100       PS  1999.0  Strategy
# 220    StarCraft II: Wings of Liberty       PC  2010.0  Strategy
# 274    Warcraft II: Tides of Darkness       PC  1995.0  Strategy
# 340  Pok\xc3\xa9mon Trading Card Game        G  1998.0  Strategy
#
#              publisher  na_sales  eu_sales  jp_sales  other_sales  \
# 170           Nintendo      3.18      1.24      0.94         0.09
# 209  Eidos Interactive      2.79      1.89      0.00         0.33
# 220         Activision      2.58      1.69      0.00         0.59
# 274         Activision      1.70      2.27      0.00         0.23
# 340           Nintendo      1.49      0.73      1.38         0.10
#
#      global_sales  critic_score  critic_count  user_score  user_count rating  \
# 170          5.45           NaN           NaN         NaN         NaN    NaN
# ...

# %%
df[df["date"] > "2017-09-10"].head()
# Out:
#                                                    name platform    year  \
# 16001  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV  2017.0
#
#               genre publisher  na_sales  eu_sales  jp_sales  other_sales  \
# 16001  Role-Playing      Sega       0.0       0.0      0.02          0.0
#
#        global_sales  critic_score  critic_count  user_score  user_count  \
# 16001          0.02           NaN           NaN         NaN         NaN
#
#       rating        date
# 16001    NaN  2017-09-16

# %%
is_strategy = df["genre"] == "Strategy"
is_pc = df["platform"] == "PC"

df[is_strategy & is_pc].head()
# Out:
#                                name platform    year     genre  \
# 220  StarCraft II: Wings of Liberty       PC  2010.0  Strategy
# 274  Warcraft II: Tides of Darkness       PC  1995.0  Strategy
# 518    Command & Conquer: Red Alert       PC  1996.0  Strategy
# 659                  Theme Hospital       PC  1997.0  Strategy
# 809                  Sim Theme Park       PC  1998.0  Strategy
#
#               publisher  na_sales  eu_sales  jp_sales  other_sales  \
# 220          Activision      2.58      1.69       0.0         0.59
# 274          Activision      1.70      2.27       0.0         0.23
# 518  Virgin Interactive      1.37      1.34       0.0         0.14
# 659     Electronic Arts      2.30      0.10       0.0         0.00
# 809     Electronic Arts      2.04      0.04       0.0         0.00
#
#      global_sales  critic_score  critic_count  user_score  user_count rating  \
# 220          4.85          93.0          82.0         8.2      3057.0      T
# ...

# %%
df[(df["publisher"] == "Nintendo") & (df["genre"] == "Strategy")].head()
# Out:
#                                   name platform    year     genre publisher  \
# 170                    Pokemon Stadium      N64  1999.0  Strategy  Nintendo
# 340   Pok\xc3\xa9mon Trading Card Game        G  1998.0  Strategy  Nintendo
# 553           Pok\xc3\xa9mon Stadium 2      N64  2000.0  Strategy  Nintendo
# 1136                            Pikmin       GC  2001.0  Strategy  Nintendo
# 1422           Pocket Monsters Stadium      N64  1998.0  Strategy  Nintendo
#
#       na_sales  eu_sales  jp_sales  other_sales  global_sales  critic_score  \
# 170       3.18      1.24      0.94         0.09          5.45           NaN
# 340       1.49      0.73      1.38         0.10          3.70           NaN
# 553       1.02      0.36      1.13         0.23          2.73           NaN
# 1136      0.78      0.25      0.56         0.04          1.63          89.0
# 1422      0.00      0.00      1.37         0.00          1.37           NaN
#
# ...

# %%
is_strategy_or_simulation = df["genre"].isin(["Strategy", "Simulation"])

df[is_strategy_or_simulation]
# Out:
#                                      name platform    year       genre  \
# 10                             Nintendogs       DS  2005.0  Simulation
# 43            Animal Crossing: Wild World       DS  2005.0  Simulation
# 72              Animal Crossing: New Leaf      3DS  2012.0  Simulation
# 88                             The Sims 3       PC  2009.0  Simulation
# 159                          Cooking Mama       DS  2006.0  Simulation
# ...                                   ...      ...     ...         ...
# 17385    Medieval: Total War Gold Edition       PC  2006.0    Strategy
# 17389  Tetsudou Seminar: Oote Shitetsuhen       DS  2009.0  Simulation
# 17395                            BC Kings       PC  2008.0    Strategy
# 17396                       CivCity: Rome       PC  2006.0    Strategy
# 17404        Fashion Designer: Style Icon       DS  2007.0  Simulation
#
#                   publisher  na_sales  eu_sales  jp_sales  other_sales  \
# ...
