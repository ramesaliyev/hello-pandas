# %%
import pandas as pd
df = pd.read_csv('./datasets/game_sales.csv')

# %%
df.head()
# Out:
#                        name platform    year         genre publisher  \
# 0                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue        G  1996.0  Role-Playing  Nintendo
#
#    na_sales  eu_sales  jp_sales  other_sales  global_sales  critic_score  \
# 0     41.36     28.96      3.77         8.45         82.54          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.80      3.79         3.29         35.57          82.0
# 3     15.61     10.95      3.28         2.95         32.78          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    critic_count  user_score  user_count rating        date
# ...

# %%
# Slicing lists.
breeds = ["Labrador", "Poodle",
          "Chow Chow", "Schnauzer",
          "Labrador", "Chihuahua",
          "St. Bernard"]

# Final value is not included.
print(breeds[2:5])
print(breeds[:5])
print(breeds[:])
# Out:
# ['Chow Chow', 'Schnauzer', 'Labrador']
# ['Labrador', 'Poodle', 'Chow Chow', 'Schnauzer', 'Labrador']
# ['Labrador', 'Poodle', 'Chow Chow', 'Schnauzer', 'Labrador', 'Chihuahua', 'St. Bernard']

# %%
# Slicing DataFrames.
# First sort the index.

indexed = df.set_index(['platform', 'genre']).sort_index()
indexed.head()
# Out:
#                                         name    year     publisher  na_sales  \
# platform genre
# 2600     Action                      Frogger  1981.0  Parker Bros.      2.06
#          Action  E.T.: The Extra Terrestrial  1981.0         Atari      1.84
#          Action                       Combat  1977.0         Atari      1.17
#          Action                   Spider-Man  1981.0  Parker Bros.      0.87
#          Action              Custers Revenge  1981.0      Mystique      0.76
#
#                  eu_sales  jp_sales  other_sales  global_sales  critic_score  \
# platform genre
# 2600     Action      0.12       0.0         0.02          2.20           NaN
#          Action      0.11       0.0         0.02          1.97           NaN
#          Action      0.07       0.0         0.01          1.25           NaN
#          Action      0.05       0.0         0.01          0.93           NaN
#          Action      0.05       0.0         0.01          0.82           NaN
#
# ...

# %%
# Slicing the outer index level
# Final value is included.

indexed.loc["PC":"PS4"]
# Out:
#                                                       name    year  \
# platform genre
# PC       Action                               Guild Wars 2  2012.0
#          Action                             Tomb Raider II  1997.0
#          Action                         Grand Theft Auto V  2015.0
#          Action                                Tomb Raider  1996.0
#          Action              Grand Theft Auto: San Andreas  2005.0
# ...                                                    ...     ...
# PS4      Strategy           SD Gundam G Generation Genesis  2016.0
#          Strategy                     Grand Ages: Medieval  2015.0
#          Strategy                Nobunaga no Yabou: Souzou  2014.0
#          Strategy  Nobunagas Ambition: Sphere of Influence  2014.0
#          Strategy                    Battle Worlds: Kronos  2016.0
#
#                               publisher  na_sales  eu_sales  jp_sales  \
# platform genre
# ...

# %%
# Slicing the inner index levels
indexed.loc[('PC', 'Platform'):('PS4', 'Sports')]
# Out:
#                                           name    year  \
# platform genre
# PC       Platform            Sonic Generations  2011.0
#          Platform               Rayman Origins  2012.0
#          Platform        Mirrors Edge Catalyst  2016.0
#          Platform                 Mirrors Edge  2009.0
#          Platform                      Trine 2  2011.0
# ...                                        ...     ...
# PS4      Sports     Mark McMorris Infinite Air  2016.0
#          Sports              Rugby Challenge 3  2016.0
#          Sports            Tour de France 2014  2014.0
#          Sports    Dino Dinis Kick Off Revival  2016.0
#          Sports           R.B.I. Baseball 2016  2016.0
#
#                                 publisher  na_sales  eu_sales  jp_sales  \
# platform genre
# PC       Platform                    Sega      0.02      0.07       0.0
#          Platform                 Ubisoft      0.00      0.06       0.0
# ...

# %%
# Slicing columns
indexed.loc[:, "name":"publisher"]
# Out:
#                                           name    year               publisher
# platform genre
# 2600     Action                        Frogger  1981.0            Parker Bros.
#          Action    E.T.: The Extra Terrestrial  1981.0                   Atari
#          Action                         Combat  1977.0                   Atari
#          Action                     Spider-Man  1981.0            Parker Bros.
#          Action                Custers Revenge  1981.0                Mystique
# ...                                        ...     ...                     ...
# XOne     Sports              Rugby Challenge 3  2016.0    Alternative Software
#          Strategy               State of Decay  2015.0  Microsoft Game Studios
#          Strategy        Angry Birds Star Wars  2013.0              Activision
#          Strategy                       XCOM 2  2016.0    Take-Two Interactive
#          Strategy        Battle Worlds: Kronos  2016.0            Nordic Games
#
# ...

# %%
# Slice by rows and columns.
indexed.loc[('PC', 'Platform'):('PS4', 'Sports'), "name":"publisher"]
# Out:
#                                           name    year               publisher
# platform genre
# PC       Platform            Sonic Generations  2011.0                    Sega
#          Platform               Rayman Origins  2012.0                 Ubisoft
#          Platform        Mirrors Edge Catalyst  2016.0         Electronic Arts
#          Platform                 Mirrors Edge  2009.0         Electronic Arts
#          Platform                      Trine 2  2011.0  Focus Home Interactive
# ...                                        ...     ...                     ...
# PS4      Sports     Mark McMorris Infinite Air  2016.0       FuRyu Corporation
#          Sports              Rugby Challenge 3  2016.0    Alternative Software
#          Sports            Tour de France 2014  2014.0  Focus Home Interactive
#          Sports    Dino Dinis Kick Off Revival  2016.0               Avanquest
#          Sports           R.B.I. Baseball 2016  2016.0                 MLB.com
#
# ...

# %%
bydates = df.set_index('date').sort_index()

# Slice by dates
bydates.loc['2016-11-17':'2016-11-18']
# Out:
#                                       name platform    year     genre  \
# date
# 2016-11-17                           WRC 6       PC  2016.0    Racing
# 2016-11-18  One Piece: Daikaizoku Coliseum      3DS  2016.0  Fighting
#
#                      publisher  na_sales  eu_sales  jp_sales  other_sales  \
# date
# 2016-11-17               PQube       0.0      0.01      0.00          0.0
# 2016-11-18  Namco Bandai Games       0.0      0.00      0.03          0.0
#
#             global_sales  critic_score  critic_count  user_score  user_count  \
# date
# 2016-11-17          0.01           NaN           NaN         NaN         NaN
# 2016-11-18          0.03           NaN           NaN         NaN         NaN
#
#            rating
# date
# 2016-11-17    NaN
# 2016-11-18    NaN

# %%
# Slice by partial dates
# Gets between 2016-01-01 and 2017-12-31

bydates.loc['2016':'2017']
# Out:
#                                                          name platform  \
# date
# 2016-01-01  God Eater Off Shot:Shiou-hen Twin Pack & Anima...      PS4
# 2016-01-01                                      Battlefield 1       PC
# 2016-01-02                               Shirogane x Spirits!      PSV
# 2016-01-02                           Norn + Nonette: Act Tune      PSV
# 2016-01-02                       Sengoku Otome: Legend Battle      PSV
# ...                                                       ...      ...
# 2016-12-23                                    Far Cry: Primal       PC
# 2016-12-23                                   Final Fantasy XV     XOne
# 2016-12-23                                               Lumo      PS4
# 2016-12-25                                   Final Fantasy XV      PS4
# 2016-12-25                        Ao no Kanata no Four Rhythm      PSV
#
#               year         genre                 publisher  na_sales  \
# date
# ...

# %%
# Subsetting by row/column number.

# loc and iloc same for df since it's integer indexed.
# loc includes end value, iloc does not.

df.loc[2:4]
# Out:
#                        name platform    year         genre publisher  \
# 2            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue        G  1996.0  Role-Playing  Nintendo
#
#    na_sales  eu_sales  jp_sales  other_sales  global_sales  critic_score  \
# 2     15.68     12.80      3.79         3.29         35.57          82.0
# 3     15.61     10.95      3.28         2.95         32.78          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    critic_count  user_score  user_count rating        date
# 2          73.0         8.3       712.0      E  2008-11-16
# 3          73.0         8.0       193.0      E  2009-11-25
# 4           NaN         NaN         NaN    NaN  1996-08-17

# %%
df.iloc[2:4]
# Out:
#                 name platform    year   genre publisher  na_sales  eu_sales  \
# 2     Mario Kart Wii      Wii  2008.0  Racing  Nintendo     15.68     12.80
# 3  Wii Sports Resort      Wii  2009.0  Sports  Nintendo     15.61     10.95
#
#    jp_sales  other_sales  global_sales  critic_score  critic_count  \
# 2      3.79         3.29         35.57          82.0          73.0
# 3      3.28         2.95         32.78          80.0          73.0
#
#    user_score  user_count rating        date
# 2         8.3       712.0      E  2008-11-16
# 3         8.0       193.0      E  2009-11-25

# %%
df.iloc[2:4, 0:4]
# Out:
#                 name platform    year   genre
# 2     Mario Kart Wii      Wii  2008.0  Racing
# 3  Wii Sports Resort      Wii  2009.0  Sports

# %%
bydates.iloc[3:5]
# Out:
#                 name platform    year   genre publisher  na_sales  eu_sales  \
# date
# 1977-11-10    Combat     2600  1977.0  Action     Atari      1.17      0.07
# 1978-04-23  Home Run     2600  1978.0  Sports     Atari      0.14      0.01
#
#             jp_sales  other_sales  global_sales  critic_score  critic_count  \
# date
# 1977-11-10       0.0         0.01          1.25           NaN           NaN
# 1978-04-23       0.0         0.00          0.15           NaN           NaN
#
#             user_score  user_count rating
# date
# 1977-11-10         NaN         NaN    NaN
# 1978-04-23         NaN         NaN    NaN
